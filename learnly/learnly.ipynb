# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import openai
from dotenv import load_dotenv
from IPython.core.magic import register_cell_magic
from IPython.display import display, Markdown

from learnly.engine import LearnlyEngine


# Загружаем переменные окружения из файла .env
load_dotenv()

# Устанавливаем API ключ для OpenAI
openai.api_key = os.getenv('OPENAI_API_KEY')


engine = LearnlyEngine()

@register_cell_magic
def check_solution(line, cell):
   """Магическая команда для проверки решений"""
   try:
       # Выполняем код пользователя
       exec(cell, globals())
       # Проверяем решение
       engine.check_solution(cell, globals())
   except Exception as e:
       display(Markdown(f"❌ Ошибка в коде: {str(e)}"))
       engine.create_solution_cell(engine.tasks[engine.current_task]['problem'])


engine.start_lesson()
# Out:
# # Добро пожаловать в Learnly!
# Это интерактивный обучающий ноутбук.
# Как выполнять задания:
# 1. В появившейся ячейке напишите своё решение
# 2. Запустите ячейку (Shift + Enter)
# 3. Получите обратную связь и следующее задание!
# ### 1. Часть
# Добро пожаловать на урок по Python! Сегодня мы познакомимся с основными концепциями языка.
# HBox(children=(Button(description='Дальше', icon='arrow-right', style=ButtonStyle(button_color='#E6F7FF', font…
# ### 2. Задание
# Напишите функцию, которая принимает два числа и возвращает их сумму.
# Textarea(value='', description='Ваш ответ:', placeholder='Введите ваш ответ здесь...', rows=5, style=TextStyle…
# HBox(children=(Button(description='Дальше', icon='arrow-right', style=ButtonStyle(button_color='#E6F7FF', font…
# 📝 **Пример кода:**
# ```python
# print('Hello, world!')
# ```
# 💡 **Подсказка:** Python – это интерпретируемый язык, удобный для быстрого прототипирования.
