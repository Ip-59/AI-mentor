# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from IPython.core.magic import register_cell_magic
from IPython.display import display, Markdown

from learnly.engine import LearnlyEngine

engine = LearnlyEngine()

@register_cell_magic
def check_solution(line, cell):
   """Магическая команда для проверки решений"""
   try:
       # Выполняем код пользователя
       exec(cell, globals())
       # Проверяем решение
       engine.check_solution(cell, globals())
   except Exception as e:
       display(Markdown(f"❌ Ошибка в коде: {str(e)}"))
       engine.create_solution_cell(engine.tasks[engine.current_task]['title'])

# Показываем приветствие и первое задание
engine.show_welcome()
# Out:
# # Добро пожаловать в Learnly!
# Это интерактивный обучающий ноутбук.
# Как выполнять задания:
# 1. В появившейся ячейке напишите своё решение
# 2. Запустите ячейку (Shift + Enter)
# 3. Получите обратную связь и следующее задание!
# 💡 Нужна подсказка? Напишите 'hint' или 'help' в ячейке с %%check_solution
# ### Задание 1
# Создайте переменную x и присвойте ей значение 42

# %%
# %%check_solution
#
# # Создайте переменную x и присвойте ей значение 42
# # Напишите ваше решение здесь:
# x = 42
# Out:
# ✅ Отлично! Задание выполнено правильно!
# ### Задание 2
# Создайте список numbers, содержащий числа от 1 до 5

# %%
# %%check_solution
#
# # Создайте список numbers, содержащий числа от 1 до 5
# # Напишите ваше решение здесь:
# numbers = [1, 2, 3, 4, 5]
# Out:
# ✅ Превосходно! Вы справились со вторым заданием!
# ### Задание 3
# Напишите функцию square(n), которая возвращает квадрат числа n

# %%
# %%check_solution
#
# # Напишите функцию square(n), которая возвращает квадрат числа n
# # Напишите ваше решение здесь:

# %%
# %%check_solution
#
# # Создайте переменную x и присвойте ей значение 42
# # Напишите ваше решение здесь:

# %%
# %%check_solution
#
# # Создайте переменную x и присвойте ей значение 42
# # Напишите ваше решение здесь:
# x = ...
# Out:
# ❌ Нужно создать переменную x со значением 42

# %%
# %%check_solution
#
# # Создайте переменную x и присвойте ей значение 42
# # Напишите ваше решение здесь:

# %%
# %%check_solution
#
# # Создайте переменную x и присвойте ей значение 42
# # Напишите ваше решение здесь:
# x = 1
# Out:
# ❌ Нужно создать переменную x со значением 42

# %%
# %%check_solution
#
# # Создайте переменную x и присвойте ей значение 42
# # Напишите ваше решение здесь:

# %%
# %%check_solution
#
# # Создайте переменную x и присвойте ей значение 42
# # Напишите ваше решение здесь:
# x = 42
# Out:
# ✅ Отлично! Задание выполнено правильно!
# ### Задание 2
# Создайте список numbers, содержащий числа от 1 до 5

# %%
# %%check_solution
#
# # Создайте список numbers, содержащий числа от 1 до 5
# # Напишите ваше решение здесь:

# %%
# %%check_solution
#
# # Создайте список numbers, содержащий числа от 1 до 5
# # Напишите ваше решение здесь:
# Out:
# ❌ Список numbers должен содержать числа от 1 до 5 в порядке возрастания

# %%
# %%check_solution
#
# # Создайте список numbers, содержащий числа от 1 до 5
# # Напишите ваше решение здесь:
