# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.magic import register_cell_magic
from IPython.display import display, Markdown

from learnly.engine import LearnlyEngine

engine = LearnlyEngine()

@register_cell_magic
def check_solution(line, cell):
   """Магическая команда для проверки решений"""
   try:
       # Выполняем код пользователя
       exec(cell, globals())
       # Проверяем решение
       engine.check_solution(cell, globals())
   except Exception as e:
       display(Markdown(f"❌ Ошибка в коде: {str(e)}"))
       engine.create_solution_cell(engine.tasks[engine.current_task]['problem'])

# Показываем приветствие и первое задание
engine.show_welcome()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 from IPython.core.magic import register_cell_magic
#       2 from IPython.display import display, Markdown
# ----> 4 from learnly.engine import LearnlyEngine
#       6 engine = LearnlyEngine()
#       8 @register_cell_magic
#       9 def check_solution(line, cell):
#
# File e:\AI-mentor\learnly\learnly\engine.py:7
#       4 from IPython.display import display, Markdown
#       5 from IPython.core.magic import register_line_magic, register_cell_magic
# ----> 7 from .tasks import generate_ml_task
#      10 @register_line_magic
#      11 def reload_learnly(line):
#      12     """Перезагружает модуль LearnlyEngine"""
#
# File e:\AI-mentor\learnly\learnly\tasks.py:41
#       1 # Обращаемся к AI и просим его написать задание (на основе контекста урока). Вот пример:
#       2 # {
#       3 #     'problem': 'Создайте переменную x и присвойте ей значение 42',
#    (...)
#      38 #     }
#      39 #}
# ---> 41 import openai
#      44 def generate_ml_task(context: str = None) -> dict:
#      45     """
#      46     Генерирует задание по машинному обучению с помощью OpenAI API.
#      47
#      48     :param context: Контекст урока (например, предыдущие задания или тема).
#      49     :return: Словарь с заданием, подсказкой, функцией проверки и сообщениями.
#      50     """
#
# ModuleNotFoundError: No module named 'openai'

# %%
# %%check_solution
#
# # Создайте и обучите модель классификации K-Nearest Neighbors с помощью библиотеки scikit-learn.
# # Напишите ваше решение здесь:
# "skip"
# Out:
# UsageError: Cell magic `%%check_solution` not found.

# %%
# %%check_solution
#
# # Создайте модель дерева решений для классификации с помощью библиотеки scikit-learn.
# # Напишите ваше решение здесь:
# "skip"
# Out:
# UsageError: Cell magic `%%check_solution` not found.
